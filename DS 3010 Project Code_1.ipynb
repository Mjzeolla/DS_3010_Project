# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#Load the CSV File from the repo
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Prints  basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#Count the number of null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Transforms the categorical values into binary values using LabelEncoder from Sklearn
# sex and smoker are binary, and region is on a range from 0 - 4
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df.sex = encoder.fit_transform(df.sex)

df.smoker = encoder.fit_transform(df.smoker)

region = pd.get_dummies(df['region'])
#     df = df.drop('region', axis=1)

df = pd.concat([df, region], axis=1)
df= df.loc[:,~df.columns.duplicated()]
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northeast  \
# 0   19    0  27.900         0       1  southwest  16884.92400          0
# 1   18    1  33.770         1       0  southeast   1725.55230          0
# 2   28    1  33.000         3       0  southeast   4449.46200          0
# 3   33    1  22.705         0       0  northwest  21984.47061          0
# 4   32    1  28.880         0       0  northwest   3866.85520          0
#
#    northwest  southeast  southwest
# 0          0          0          1
# 1          0          1          0
# 2          0          1          0
# 3          1          0          0
# 4          1          0          0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print('The shape of the data is: ' + str(df.shape))
# Out:
# The shape of the data is: (1338, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1338 non-null   int64
#  1   sex        1338 non-null   int32
#  2   bmi        1338 non-null   float64
#  3   children   1338 non-null   int64
#  4   smoker     1338 non-null   int32
#  5   region     1338 non-null   object
#  6   charges    1338 non-null   float64
#  7   northeast  1338 non-null   uint8
#  8   northwest  1338 non-null   uint8
#  9   southeast  1338 non-null   uint8
#  10  southwest  1338 non-null   uint8
# dtypes: float64(2), int32(2), int64(2), object(1), uint8(4)
# memory usage: 68.1+ KB

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges    northeast    northwest    southeast    southwest
# count   1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean   13270.422265     0.242152     0.242900     0.272048     0.242900
# std    12110.011237     0.428546     0.428995     0.445181     0.428995
# min     1121.873900     0.000000     0.000000     0.000000     0.000000
# 25%     4740.287150     0.000000     0.000000     0.000000     0.000000
# 50%     9382.033000     0.000000     0.000000     0.000000     0.000000
# 75%    16639.912515     0.000000     0.000000     1.000000     0.000000
# max    63770.428010     1.000000     1.000000     1.000000     1.000000

# %%
df.median(numeric_only=True)
# Out:
# age            39.000
# sex             1.000
# bmi            30.400
# children        1.000
# smoker          0.000
# charges      9382.033
# northeast       0.000
# northwest       0.000
# southeast       0.000
# southwest       0.000
# dtype: float64

# %%
corr_data = df.corr()
fig = plt.figure(figsize = [10,5])
sns.heatmap(corr_data,annot = True, center = 0)
plt.show()

# %%
sns.scatterplot(x='age', y='charges', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x='bmi', y='charges', data=df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x='children', y='charges', data=df)
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
sns.histplot(x='charges', data=df)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Count'>

# %%
sns.pairplot(df, vars=["age", 'bmi','children','charges'])
plt.show()

# %%
fig, axes = plt.subplots(2,1, figsize=(18, 10))
sns.histplot(df['region'], kde=True, ax=axes[0]) 
axes[0].set_title('Region Distribution')
sns.histplot(df['age'], kde=True, ax=axes[1]) 
axes[1].set_title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('EDA Data Plots')

sns.boxplot(ax=axes[0, 0], data=df, x='smoker', y='charges')
axes[0,0].set_title('Smoker vs Charges')
sns.boxplot(ax=axes[0, 1], data=df, x='children', y='charges')
axes[0,1].set_title('Children vs Charges')
sns.boxplot(ax=axes[1, 0], data=df, x='region', y='charges')
axes[1,0].set_title('Region vs Charges')
sns.boxplot(ax=axes[1, 1], data=df, x='sex', y='charges')
axes[1,1].set_title('Sex vs Charges')
# Out:
# Text(0.5, 1.0, 'Sex vs Charges')

# %%
sns.boxplot(x = 'smoker', y = 'charges', data = df)
plt.title('Smoker vs Charges')
# Out:
# Text(0.5, 1.0, 'Smoker vs Charges')

# %%
x = df.drop(['charges', 'region'], axis=1)
y = df['charges']

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, train_size = 0.7, random_state = 1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error

results = {}

basic_lin_reg = LinearRegression()
basic_lin_reg.fit(X_train, y_train)
rSqrted = basic_lin_reg.score(X_test, y_test)
print(basic_lin_reg.intercept_)
print(basic_lin_reg.coef_)
print(rSqrted)
adj_rSqrted = 1 - (1-rSqrted)*(len(y)-1)/(len(y)-X_train.shape[1]-1)
print(adj_rSqrted)
results['basic_lin_reg'] = [rSqrted, adj_rSqrted]
# Out:
# 13276.698553898505
# [3528.98273114 -141.35911014 1961.65520818  421.55016415 9733.78688309
#   230.14079939   99.89180015 -176.86423097 -143.927575  ]
# 0.7405989316927211
# 0.738840942524976

# %%
#Linear Regression Model on Smoker, BMI and Age

x_corr = df.drop(['charges', 'region', 'southeast', 'southwest','northeast', 'children', 'northwest'], axis=1)
y_corr = df['charges']
X_corr_train, X_corr_test, y_corr_train, y_corr_test = train_test_split(x_corr,y_corr, test_size = 0.3, train_size = 0.7, random_state = 1)
X_corr_train.head()
results = {}

scaler = StandardScaler()
X_corr_train = scaler.fit_transform(X_corr_train)
X_corr_test = scaler.transform(X_corr_test)

basic_corr_lin_reg = LinearRegression()
basic_corr_lin_reg.fit(X_corr_train, y_corr_train)
rSqrted_corr = basic_corr_lin_reg.score(X_corr_test, y_corr_test)
print(basic_corr_lin_reg.intercept_)
print(basic_corr_lin_reg.coef_)
print(rSqrted_corr)
adj_rSqrted_corr = 1 - (1-rSqrted_corr)*(len(y)-1)/(len(y)-X_corr_train.shape[1]-1)
print(adj_rSqrted_corr)
results['basic_corr_lin_reg'] = [rSqrted_corr, adj_rSqrted_corr]
# Out:
# 13276.698553898505
# [3545.64880072 -125.96549644 1863.5444008  9726.81785855]
# 0.7346651621337207
# 0.7338689585692307

# %%
from sklearn.linear_model import Ridge
basic_ridge_reg = Ridge()
basic_ridge_reg.fit(X_train, y_train)
rSqrted = basic_ridge_reg.score(X_test, y_test)
print(basic_ridge_reg.intercept_)
print(basic_ridge_reg.coef_)
print(rSqrted)
adj_rSqrted = 1 - (1-rSqrted)*(len(y)-1)/(len(y)-X_train.shape[1]-1)
print(adj_rSqrted)
results['basic_ridge_reg'] = [rSqrted, adj_rSqrted]
# Out:
# 13276.698553898505
# [3525.36268866 -140.42856602 1959.75453317  421.10911164 9723.27965954
#   229.78840589   99.43309692 -176.09780566 -143.90979165]
# 0.7406122602486029
# 0.7388543614099263

# %%
from sklearn.linear_model import Lasso
import math

basic_lasso_reg = Lasso(alpha=0.2)
basic_lasso_reg.fit(X_train, y_train)
rSqrted = basic_lasso_reg.score(X_test, y_test)
print(basic_lasso_reg.intercept_)
print(basic_lasso_reg.coef_)
print(rSqrted)
adj_rSqrted = 1 - (1-rSqrted)*(len(y)-1)/(len(y)-X_train.shape[1]-1)
print(adj_rSqrted)
results['basic_lasso_reg'] = [rSqrted, adj_rSqrted]


pred = basic_lasso_reg.predict(X_test)
print("Lasso MSE is: ", mean_squared_error(y_test, pred))
print("Sqrt MSE is: ",  math.sqrt(mean_squared_error(y_test, pred)))
# Out:
# 13276.698553898505
# [3528.8256897  -141.1238797  1961.36591023  421.35036236 9733.56441875
#   344.15638826  213.58458479  -58.71075601  -27.06356053]
# 0.7405967362169912
# 0.738838732170269
# Lasso MSE is:  36761767.48752917
# Sqrt MSE is:  6063.148314822026

# %%
from sklearn.model_selection import GridSearchCV

grid_params_lasso =  {  'alpha': np.arange(0.01, 1, 0.005)}

grid_lasso = Lasso()

grid_lasso = GridSearchCV(estimator = grid_lasso, param_grid = grid_params_lasso, cv = 3, n_jobs = -1, verbose = 2)
grid_lasso.fit(X_train, y_train)

print("The best params are: ", grid_lasso.best_params_)

grid_lasso = grid_lasso.best_estimator_
# Out:
# Fitting 3 folds for each of 198 candidates, totalling 594 fits
# The best params are:  {'alpha': 0.9899999999999999}

# %%
rSqrted = grid_lasso.score(X_test, y_test)
print(grid_lasso.intercept_)
print(grid_lasso.coef_)
print(rSqrted)
adj_rSqrted = 1 - (1-rSqrted)*(len(y)-1)/(len(y)-X_train.shape[1]-1)
print(adj_rSqrted)
results['best_lasso_reg'] = [rSqrted, adj_rSqrted]


pred = grid_lasso.predict(X_test)
print("Best Lasso MSE is: ", mean_squared_error(y_test, pred))
print("Sqrt MSE is: ",  math.sqrt(mean_squared_error(y_test, pred)))
# Out:
# 13276.698553898505
# [3528.1737312  -140.20773761 1960.21236941  420.56450465 9732.68404284
#   343.02026788  212.56124165  -58.28436052  -26.80627887]
# 0.7405878072434622
# 0.7388297426841182
# Best Lasso MSE is:  36763032.8719503
# Sqrt MSE is:  6063.252664366734

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree

basic_decision_tree = DecisionTreeRegressor()
basic_decision_tree.fit(X_train, y_train)

score = basic_decision_tree.score(X_test, y_test)
print('Decision tree accuracy: ', score)

plt.figure(figsize=(15,15))
tree.plot_tree(basic_decision_tree, max_depth=1, fontsize=10, feature_names=df.columns, filled=True)
plt.show()
# Out:
# Decision tree accuracy:  0.7238524533575466

# %%
random_forest = RandomForestRegressor()
random_forest.fit(X_train, y_train)

score = random_forest.score(X_test, y_test)
print('Random Forest tree accuracy: ', score)
# Out:
# Random Forest tree accuracy:  0.8357947118442471

# %%
param_grid = {
    'max_depth': [100, 120, 140, 160, 180, 200],
    'max_features': [2, 3],
    'min_samples_leaf': [1, 2, 3, 4, 5],
    'min_samples_split': [5, 6, 7, 8],
    'n_estimators': [50, 100, 120 ,150, 200, 300, 1000]
}

rf = RandomForestRegressor()

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 3, n_jobs = -1, verbose = 2)

grid_search.fit(X_train, y_train)
grid_search.best_params_
print("The best params are: ", grid_search.best_params_)

grid_random_forest = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 1680 candidates, totalling 5040 fits
# The best params are:  {'max_depth': 200, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 120}

# %%
score = grid_random_forest.score(X_test, y_test)
print('Random Forest tree accuracy: ', score)

adj_rSqrted = 1 - (1-score)*(len(y)-1)/(len(y)-X_train.shape[1]-1)
print(adj_rSqrted)

pred = grid_random_forest.predict(X_test)
print("Sqrt MSE is: ",  math.sqrt(mean_squared_error(y_test, pred)))

results['best_random_forest'] = [score, adj_rSqrted]
# Out:
# Random Forest tree accuracy:  0.842899659277295
# 0.8418349732332406
# Sqrt MSE is:  4718.446524184116

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_obj = PolynomialFeatures(degree=2)
poly_x = poly_obj.fit_transform(x)
X_poly_train, X_poly_test, y_poly_train, y_poly_test = train_test_split(poly_x,y, test_size = 0.3, train_size = 0.7, random_state = 1)
basic_poly_reg = LinearRegression()
basic_poly_reg.fit(X_poly_train, y_poly_train)

rSqrted = basic_poly_reg.score(X_poly_test, y_poly_test)
print(basic_poly_reg.intercept_)
print(basic_poly_reg.coef_)
print(rSqrted)
adj_rSqrted = 1 - (1-rSqrted)*(len(y)-1)/(len(y)-X_train.shape[1]-1)
print(adj_rSqrted)

results['basic_poly_reg'] = [rSqrted, adj_rSqrted]

poly_pred = basic_poly_reg.predict(X_poly_test)
print("Poly MSE is: ", mean_squared_error(y_poly_test, poly_pred))
print("Sqrt MSE is: ",  math.sqrt(mean_squared_error(y_poly_test, poly_pred)))
# Out:
# -6449519344277.836
# [ 6.44951934e+12 -7.14016997e+01 -7.80504592e+02  2.68074401e+02
#   1.05283802e+03 -8.42625842e+03 -1.19673858e+02 -1.87488785e+02
#   7.31959165e+02 -4.24796521e+02  3.72319161e+00  2.40387289e+01
#   1.10225408e+00  5.59136576e+00 -7.07837118e+00 -4.42158606e+01
#  -4.71217726e+01  1.58415090e+01  4.09442444e+00 -7.80504592e+02
#   1.19891774e+01 -1.27373267e+02 -6.41266925e+02 -2.56154850e+02
#  -6.38609247e+02  3.87030471e+02 -2.72770966e+02 -5.53442254e+00
#  -1.53342847e+01  1.44548540e+03  1.32437948e+02  1.16394126e+02
#  -3.21598642e+01  5.14021908e+01 -9.02340135e+01 -7.86240177e+02
#   1.53914528e+02  6.57611599e+02  1.44659785e+02  9.66521034e+01
#  -8.42625842e+03 -1.85395639e+03 -2.56888497e+03 -2.59896383e+03
#  -1.40445324e+03 -1.19673858e+02  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -1.87488785e+02  0.00000000e+00  0.00000000e+00
#   7.31959165e+02  0.00000000e+00 -4.24796521e+02]
# 0.8456199804922517
# 0.8445737303600456
# Poly MSE is:  21878222.729731895
# Sqrt MSE is:  4677.4162450793165

# %%
residual = (y_test - poly_pred)
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize =(5,5))
sns.regplot(x=poly_pred,y=residual,ax=ax, lowess=True, line_kws=dict(color="r"))
ax.set(ylabel='Residuals',xlabel='Predicted Charges')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Predicted Charges')]

# %%
from prettytable import PrettyTable

table = PrettyTable()

table.field_names = ['Model', 'R^2', 'Adj. R^2']
for key in results:
    if 'nn_model' not in key: table.add_row([key, str(format(results[key][0],'.5f')), str(format(results[key][1],'.5f'))])

print(table)
# Out:
# +--------------------+---------+----------+
# |       Model        |   R^2   | Adj. R^2 |
# +--------------------+---------+----------+
# | basic_corr_lin_reg | 0.73467 | 0.73387  |
# |  basic_ridge_reg   | 0.74061 | 0.73885  |
# |  basic_lasso_reg   | 0.74060 | 0.73884  |
# |   best_lasso_reg   | 0.74059 | 0.73883  |
# | best_random_forest | 0.84290 | 0.84183  |
# |   basic_poly_reg   | 0.84562 | 0.84457  |
# +--------------------+---------+----------+

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


def generateNeuralNetwork():
    tf.random.set_seed(1)
    model = keras.Sequential([
        layers.Dense(256, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(1)
    ])
    model.compile(loss='mean_absolute_error', optimizer=tf.keras.optimizers.Adam(0.001), metrics=['mse'])
    return model

# %%
base_model = generateNeuralNetwork()
history = base_model.fit(x=X_train, y=y_train, batch_size = 128, epochs=150, verbose=0)
base_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               2560
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 43,777
# Trainable params: 43,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(history.history['loss'])
plt.title('Loss Function Over Epochs')
plt.ylabel('MAE value')
plt.xlabel('No. Epochs')
plt.show()

# %%
plt.plot(history.history['mse'])
plt.title('Loss Function Over Epochs')
plt.ylabel('MSE value')
plt.xlabel('No. Epochs')
plt.show()

# %%
results['basic_nn_model'] = base_model.evaluate(X_test, y_test, verbose=0)
print(results)
# Out:
# {'basic_corr_lin_reg': [0.7346651621337207, 0.7338689585692307], 'basic_ridge_reg': [0.7406122602486029, 0.7388543614099263], 'basic_lasso_reg': [0.7405967362169912, 0.738838732170269], 'best_lasso_reg': [0.7405878072434622, 0.7388297426841182], 'best_random_forest': [0.842899659277295, 0.8418349732332406], 'basic_poly_reg': [0.8456199804922517, 0.8445737303600456], 'basic_nn_model': [1989.9034423828125, 23287926.0]}

# %%
nn_results = {}
for key in results:
    if("nn_model" in key): nn_results[key] = results[key]

pd.DataFrame(nn_results, index=['MAE Loss', 'MSE']).T
# Out:
#                    MAE Loss         MSE
# basic_nn_model  1989.903442  23287926.0

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

model = KerasRegressor(build_fn = generateNeuralNetwork)
params = {
    'batch_size': [8, 16, 32, 64, 128, 150],
    'epochs': [50, 100, 150]
}
grid = GridSearchCV(estimator= model, param_grid= params, cv=3)

grid = grid.fit(X_train, y_train, verbose = 0)
# Out:
# C:\Users\mjzeo\AppData\Local\Temp/ipykernel_21092/2613896657.py:3: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn = generateNeuralNetwork)
# 39/39 [==============================] - 0s 1ms/step - loss: 2215.9250 - mse: 25675662.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 2264.0581 - mse: 26432550.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 2239.5730 - mse: 27382898.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 2066.6245 - mse: 24345586.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 2042.6188 - mse: 24853562.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 1935.1282 - mse: 25515472.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 1797.1210 - mse: 22729696.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 1898.6248 - mse: 23670564.0000
# 39/39 [==============================] - 0s 2ms/step - loss: 1837.8596 - mse: 25108656.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2424.8867 - mse: 29792618.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2327.5552 - mse: 27186046.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2309.2708 - mse: 27060418.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2130.6816 - mse: 24788870.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2100.6816 - mse: 25222112.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2100.3667 - mse: 26800646.0000
# 20/20 [==============================] - 0s 3ms/step - loss: 1939.3105 - mse: 23850070.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2006.7877 - mse: 24675996.0000
# 20/20 [==============================] - 0s 2ms/step - loss: 2025.3960 - mse: 26034106.0000
# 10/10 [==============================] - 0s 3ms/step - loss: 2920.6624 - mse: 39986092.0000
# 10/10 [==============================] - 0s 4ms/step - loss: 2522.9331 - mse: 30537144.0000
# 10/10 [==============================] - 0s 3ms/step - loss: 2599.6074 - mse: 31781674.0000
# 10/10 [==============================] - 0s 2ms/step - loss: 2309.4021 - mse: 27103726.0000
# 10/10 [==============================] - 0s 2ms/step - loss: 2172.0408 - mse: 25794830.0000
# 10/10 [==============================] - 0s 2ms/step - loss: 2173.1489 - mse: 26981694.0000
# 10/10 [==============================] - 0s 2ms/step - loss: 2083.9788 - mse: 24441390.0000
# 10/10 [==============================] - 0s 2ms/step - loss: 2155.7563 - mse: 25615306.0000
# 10/10 [==============================] - 0s 3ms/step - loss: 2161.3184 - mse: 26878054.0000
# 5/5 [==============================] - 0s 5ms/step - loss: 3196.3330 - mse: 44756748.0000
# 5/5 [==============================] - 0s 2ms/step - loss: 2955.1885 - mse: 37885832.0000
# 5/5 [==============================] - 0s 2ms/step - loss: 2899.6223 - mse: 37355400.0000
# 5/5 [==============================] - 0s 3ms/step - loss: 2830.2456 - mse: 38235376.0000
# 5/5 [==============================] - 0s 2ms/step - loss: 2365.0627 - mse: 27954426.0000
# 5/5 [==============================] - 0s 3ms/step - loss: 2509.1716 - mse: 29313602.0000
# 5/5 [==============================] - 0s 2ms/step - loss: 2311.5774 - mse: 27159880.0000
# 5/5 [==============================] - 0s 4ms/step - loss: 2197.9248 - mse: 26051150.0000
# 5/5 [==============================] - 0s 2ms/step - loss: 2365.6389 - mse: 28111868.0000
# 3/3 [==============================] - 0s 7ms/step - loss: 3667.7812 - mse: 58440704.0000
# 3/3 [==============================] - 0s 2ms/step - loss: 3726.1914 - mse: 52507768.0000
# 3/3 [==============================] - 0s 10ms/step - loss: 3872.1394 - mse: 59511488.0000
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x00000140D76859D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 6ms/step - loss: 3119.8667 - mse: 43531456.0000
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x00000140D7635550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 4ms/step - loss: 2769.1162 - mse: 34906020.0000
# 3/3 [==============================] - 0s 9ms/step - loss: 2832.1270 - mse: 35563492.0000
# 3/3 [==============================] - 0s 5ms/step - loss: 2723.9136 - mse: 36741332.0000
# 3/3 [==============================] - 0s 4ms/step - loss: 2388.7942 - mse: 28477696.0000
# 3/3 [==============================] - 0s 6ms/step - loss: 2526.8943 - mse: 29481002.0000
# 3/3 [==============================] - 0s 8ms/step - loss: 3740.9099 - mse: 62468044.0000
# 3/3 [==============================] - 0s 5ms/step - loss: 3781.1892 - mse: 53677484.0000
# 3/3 [==============================] - 0s 9ms/step - loss: 4145.7534 - mse: 68363096.0000
# 3/3 [==============================] - 0s 6ms/step - loss: 3179.2163 - mse: 44938120.0000
# 3/3 [==============================] - 0s 6ms/step - loss: 2864.9934 - mse: 35856868.0000
# 3/3 [==============================] - 0s 4ms/step - loss: 2914.1782 - mse: 38097844.0000
# 3/3 [==============================] - 0s 7ms/step - loss: 2845.8308 - mse: 38615268.0000
# 3/3 [==============================] - 0s 5ms/step - loss: 2515.3879 - mse: 31048832.0000
# 3/3 [==============================] - 0s 8ms/step - loss: 2744.8013 - mse: 33623676.0000

# %%
best_parameters = grid.best_params_

print("Best Parameters: " + str(grid.best_params_))
# Out:
# Best Parameters: {'batch_size': 8, 'epochs': 150}

# %%
grid_search_nn = generateNeuralNetwork()
nn_history = grid_search_nn.fit(x = X_train, y = y_train, batch_size = best_parameters['batch_size'], 
                                                                                        epochs=best_parameters['epochs'] , verbose = 0)

# %%
plt.plot(nn_history.history['loss'])
plt.title('Loss Function Over Epochs')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# %%
best_model_root_mse = [math.sqrt(x) for x in nn_history.history['mse']]

plt.plot(best_model_root_mse)
plt.title('Loss Function Over Epochs')
plt.ylabel('Square Root MSE value')
plt.xlabel('No. epoch')
plt.show()

# %%
initial_model_root_mse = [math.sqrt(x) for x in history.history['mse']]
best_model_root_mse = [math.sqrt(x) for x in nn_history.history['mse']]

plt.plot(initial_model_root_mse, label='Model #1')
plt.plot(best_model_root_mse, label='Model #2')
plt.title('Loss Function Over Epochs')
plt.legend(loc="upper right")
plt.ylabel('Square Root MSE value')
plt.xlabel('No. epoch')
plt.show()

# %%
results['better_nn_model'] = grid_search_nn.evaluate(x= X_train, y=y_train, verbose=0)

# %%
nn_results = {}
for key in results:
    if("nn_model" in key): nn_results[key] = results[key]

pd.DataFrame(nn_results, index=['MAE Loss', 'MSE']).T
# Out:
#                     MAE Loss         MSE
# basic_nn_model   1989.903442  23287926.0
# better_nn_model  1584.927612  22127074.0

# %%
print("The Better NN MSE is: ", math.sqrt(nn_results['better_nn_model'][1]))
# Out:
# The Better NN MSE is:  4703.942389102996

# %%
predictions = grid_search_nn.predict(X_test)
for i, pred in enumerate(predictions):
    print("The actual is ", y_test.iloc[i], " and prediction is ", pred[0])
# Out:
# 13/13 [==============================] - 0s 3ms/step
# The actual is  1646.4297  and prediction is  1566.7516
# The actual is  11353.2276  and prediction is  11245.089
# The actual is  8798.593  and prediction is  8644.196
# The actual is  10381.4787  and prediction is  10326.182
# The actual is  2103.08  and prediction is  2067.5981
# The actual is  38746.3551  and prediction is  38101.957
# The actual is  9304.7019  and prediction is  9167.163
# The actual is  11658.11505  and prediction is  11553.013
# The actual is  3070.8087  and prediction is  3070.394
# The actual is  19539.243  and prediction is  19948.715
# The actual is  12629.8967  and prediction is  12757.335
# The actual is  11538.421  and prediction is  11705.492
# The actual is  6338.0756  and prediction is  6509.3794
# The actual is  7050.642  and prediction is  6939.837
# The actual is  1137.4697  and prediction is  1069.888
# The actual is  8968.33  and prediction is  8870.281
# The actual is  21984.47061  and prediction is  4029.2966
# The actual is  6414.178  and prediction is  6384.4253
# The actual is  28287.89766  and prediction is  12653.306
# The actual is  13462.52  and prediction is  13251.802
# The actual is  9722.7695  and prediction is  9667.945
# The actual is  40932.4295  and prediction is  40450.457
# The actual is  8026.6666  and prediction is  7895.4893
# The actual is  8444.474  and prediction is  8453.825
# The actual is  2203.47185  and prediction is  2277.3406
# The actual is  6664.68595  and prediction is  6622.062
# The actual is  8606.2174  and prediction is  8628.071
# The actual is  8283.6807  and prediction is  8221.2295
# The actual is  5375.038  and prediction is  5316.994
# The actual is  3645.0894  and prediction is  3621.6978
# The actual is  11674.13  and prediction is  11492.081
# The actual is  11737.84884  and prediction is  5057.7715
# The actual is  24873.3849  and prediction is  24580.572
# The actual is  33750.2918  and prediction is  31887.455
# The actual is  24180.9335  and prediction is  23813.79
# The actual is  9863.4718  and prediction is  9832.29
# The actual is  36837.467  and prediction is  37148.41
# The actual is  17942.106  and prediction is  17028.283
# The actual is  11856.4115  and prediction is  11570.731
# The actual is  39725.51805  and prediction is  33665.4
# The actual is  4349.462  and prediction is  4337.5474
# The actual is  11743.9341  and prediction is  11615.427
# The actual is  19749.38338  and prediction is  10729.319
# The actual is  12347.172  and prediction is  12240.241
# The actual is  4931.647  and prediction is  4870.3496
# The actual is  30259.99556  and prediction is  12759.159
# The actual is  27724.28875  and prediction is  1844.3817
# The actual is  34672.1472  and prediction is  34083.81
# The actual is  9644.2525  and prediction is  9536.539
# The actual is  14394.39815  and prediction is  14329.483
# The actual is  12557.6053  and prediction is  12936.569
# The actual is  11881.358  and prediction is  11857.78
# The actual is  2352.96845  and prediction is  2283.4138
# The actual is  9101.798  and prediction is  9089.276
# The actual is  17178.6824  and prediction is  19220.512
# The actual is  3994.1778  and prediction is  3898.1523
# The actual is  40941.2854  and prediction is  39321.785
# The actual is  12644.589  and prediction is  12461.892
# The actual is  22395.74424  and prediction is  3928.045
# The actual is  1149.3959  and prediction is  1028.0157
# The actual is  3366.6697  and prediction is  3228.62
# The actual is  13143.33665  and prediction is  13125.8955
# The actual is  18328.2381  and prediction is  20976.602
# The actual is  2690.1138  and prediction is  2606.8708
# The actual is  12741.16745  and prediction is  12706.9795
# The actual is  8765.249  and prediction is  8481.406
# The actual is  10264.4421  and prediction is  10381.978
# The actual is  22192.43711  and prediction is  12133.496
# The actual is  2709.24395  and prediction is  2615.29
# The actual is  14571.8908  and prediction is  14294.281
# The actual is  60021.39897  and prediction is  44378.26
# The actual is  58571.07448  and prediction is  40058.53
# The actual is  1743.214  and prediction is  1767.6555
# The actual is  12479.70895  and prediction is  12382.826
# The actual is  13352.0998  and prediction is  13328.878
# The actual is  41034.2214  and prediction is  40910.684
# The actual is  2789.0574  and prediction is  2741.7783
# The actual is  2867.1196  and prediction is  2871.993
# The actual is  11070.535  and prediction is  11020.111
# The actual is  10493.9458  and prediction is  10322.544
# The actual is  3167.45585  and prediction is  3047.2336
# The actual is  12269.68865  and prediction is  12056.326
# The actual is  10942.13205  and prediction is  10784.865
# The actual is  1977.815  and prediction is  2019.7936
# The actual is  39125.33225  and prediction is  39003.082
# The actual is  42112.2356  and prediction is  41897.01
# The actual is  7045.499  and prediction is  6985.7686
# The actual is  46200.9851  and prediction is  46165.56
# The actual is  10370.91255  and prediction is  10368.55
# The actual is  7749.1564  and prediction is  7541.992
# The actual is  20234.85475  and prediction is  22933.07
# The actual is  24106.91255  and prediction is  23774.785
# The actual is  13919.8229  and prediction is  13989.79
# The actual is  8871.1517  and prediction is  8818.075
# The actual is  1628.4709  and prediction is  1588.831
# The actual is  9487.6442  and prediction is  9473.507
# The actual is  9861.025  and prediction is  9766.799
# The actual is  12265.5069  and prediction is  12164.003
# The actual is  12235.8392  and prediction is  11961.97
# The actual is  6402.29135  and prediction is  6323.572
# The actual is  11356.6609  and prediction is  11175.761
# The actual is  15817.9857  and prediction is  14704.119
# The actual is  18259.216  and prediction is  17485.387
# The actual is  34779.615  and prediction is  34515.945
# The actual is  27037.9141  and prediction is  25903.77
# The actual is  18033.9679  and prediction is  21666.654
# The actual is  1737.376  and prediction is  1660.5961
# The actual is  7441.053  and prediction is  7381.7383
# The actual is  2219.4451  and prediction is  2064.749
# The actual is  11286.5387  and prediction is  11165.983
# The actual is  4415.1588  and prediction is  4439.6045
# The actual is  3981.9768  and prediction is  3961.1306
# The actual is  1632.03625  and prediction is  1614.1205
# The actual is  15555.18875  and prediction is  15754.753
# The actual is  12609.88702  and prediction is  2880.449
# The actual is  1253.936  and prediction is  1292.3551
# The actual is  6666.243  and prediction is  6512.831
# The actual is  14254.6082  and prediction is  14106.07
# The actual is  19496.71917  and prediction is  7156.7197
# The actual is  2261.5688  and prediction is  2059.7395
# The actual is  8932.084  and prediction is  8879.171
# The actual is  10736.87075  and prediction is  11003.962
# The actual is  5976.8311  and prediction is  5906.2812
# The actual is  7147.105  and prediction is  7115.3027
# The actual is  43813.8661  and prediction is  40114.484
# The actual is  9563.029  and prediction is  9538.085
# The actual is  13047.33235  and prediction is  13132.017
# The actual is  19361.9988  and prediction is  19273.652
# The actual is  43896.3763  and prediction is  43806.133
# The actual is  7740.337  and prediction is  7570.0195
# The actual is  36307.7983  and prediction is  36064.246
# The actual is  1832.094  and prediction is  1803.4987
# The actual is  7144.86265  and prediction is  7073.286
# The actual is  38282.7495  and prediction is  38436.137
# The actual is  24603.04837  and prediction is  7204.0107
# The actual is  1731.677  and prediction is  1644.9076
# The actual is  1632.56445  and prediction is  1620.7473
# The actual is  1631.8212  and prediction is  1575.8706
# The actual is  9991.03765  and prediction is  9873.7
# The actual is  7935.29115  and prediction is  7947.1836
# The actual is  14043.4767  and prediction is  13638.638
# The actual is  5934.3798  and prediction is  5957.376
# The actual is  18972.495  and prediction is  19186.133
# The actual is  14313.8463  and prediction is  14050.198
# The actual is  13607.36875  and prediction is  13592.935
# The actual is  10594.50155  and prediction is  10508.403
# The actual is  1719.4363  and prediction is  1762.9006
# The actual is  7954.517  and prediction is  7833.8384
# The actual is  1727.54  and prediction is  1596.5356
# The actual is  6686.4313  and prediction is  6512.0527
# The actual is  7152.6714  and prediction is  7007.798
# The actual is  3877.30425  and prediction is  3856.531
# The actual is  33471.97189  and prediction is  10846.912
# The actual is  11879.10405  and prediction is  11680.202
# The actual is  7804.1605  and prediction is  7603.906
# The actual is  5969.723  and prediction is  5946.086
# The actual is  9964.06  and prediction is  9915.153
# The actual is  9957.7216  and prediction is  10004.3955
# The actual is  9447.3824  and prediction is  9379.873
# The actual is  1826.843  and prediction is  1680.7819
# The actual is  3704.3545  and prediction is  3669.2249
# The actual is  49577.6624  and prediction is  49102.906
# The actual is  11946.6259  and prediction is  12107.069
# The actual is  2904.088  and prediction is  2860.8508
# The actual is  6128.79745  and prediction is  6096.767
# The actual is  1534.3045  and prediction is  1428.3103
# The actual is  38709.176  and prediction is  38916.145
# The actual is  10436.096  and prediction is  10333.107
# The actual is  11073.176  and prediction is  11065.3
# The actual is  5469.0066  and prediction is  5339.0195
# The actual is  5152.134  and prediction is  5112.895
# The actual is  3556.9223  and prediction is  3198.862
# The actual is  22412.6485  and prediction is  21774.152
# The actual is  25678.77845  and prediction is  25015.553
# The actual is  3353.4703  and prediction is  3200.1882
# The actual is  6555.07035  and prediction is  6453.8496
# The actual is  2416.955  and prediction is  2198.2463
# The actual is  14590.63205  and prediction is  14619.733
# The actual is  3732.6251  and prediction is  3662.403
# The actual is  5846.9176  and prediction is  5663.8643
# The actual is  12730.9996  and prediction is  12721.683
# The actual is  13616.3586  and prediction is  13533.2295
# The actual is  8988.15875  and prediction is  8804.954
# The actual is  7650.77375  and prediction is  7780.0923
# The actual is  3594.17085  and prediction is  3488.993
# The actual is  18246.4955  and prediction is  24431.098
# The actual is  2155.6815  and prediction is  2136.621
# The actual is  8569.8618  and prediction is  8335.7705
# The actual is  7526.70645  and prediction is  7447.4907
# The actual is  9222.4026  and prediction is  9141.665
# The actual is  14119.62  and prediction is  14056.405
# The actual is  47269.854  and prediction is  47226.77
# The actual is  3260.199  and prediction is  3274.231
# The actual is  2709.1119  and prediction is  2613.8987
# The actual is  6933.24225  and prediction is  6797.2827
# The actual is  9264.797  and prediction is  9233.468
# The actual is  7243.8136  and prediction is  7049.2793
# The actual is  2134.9015  and prediction is  1934.5339
# The actual is  11520.09985  and prediction is  11669.228
# The actual is  8233.0975  and prediction is  8247.894
# The actual is  6289.7549  and prediction is  6263.077
# The actual is  7371.772  and prediction is  7252.3696
# The actual is  12094.478  and prediction is  12143.248
# The actual is  23563.01618  and prediction is  6338.074
# The actual is  6457.8434  and prediction is  6460.909
# The actual is  1615.7667  and prediction is  1661.938
# The actual is  6600.20595  and prediction is  6470.024
# The actual is  7046.7222  and prediction is  7030.028
# The actual is  1984.4533  and prediction is  3008.6404
# The actual is  11455.28  and prediction is  11326.715
# The actual is  4137.5227  and prediction is  4009.6824
# The actual is  23244.7902  and prediction is  22591.54
# The actual is  17128.42608  and prediction is  5297.1465
# The actual is  3987.926  and prediction is  3945.4065
# The actual is  4670.64  and prediction is  4579.8174
# The actual is  47291.055  and prediction is  42518.76
# The actual is  10796.35025  and prediction is  10877.591
# The actual is  35595.5898  and prediction is  29216.955
# The actual is  1136.3994  and prediction is  1074.3032
# The actual is  38998.546  and prediction is  29830.361
# The actual is  2459.7201  and prediction is  2499.404
# The actual is  21195.818  and prediction is  21031.648
# The actual is  12268.63225  and prediction is  12126.575
# The actual is  4827.90495  and prediction is  4889.457
# The actual is  1635.73365  and prediction is  1615.7491
# The actual is  1969.614  and prediction is  1918.5242
# The actual is  4357.04365  and prediction is  4182.8794
# The actual is  10795.93733  and prediction is  2233.6038
# The actual is  17081.08  and prediction is  20893.898
# The actual is  13887.9685  and prediction is  13579.584
# The actual is  3579.8287  and prediction is  3596.4958
# The actual is  14001.2867  and prediction is  14044.756
# The actual is  47462.894  and prediction is  47404.332
# The actual is  6753.038  and prediction is  6721.9404
# The actual is  12096.6512  and prediction is  11998.168
# The actual is  10214.636  and prediction is  10265.214
# The actual is  17361.7661  and prediction is  16251.183
# The actual is  1639.5631  and prediction is  1484.2472
# The actual is  8342.90875  and prediction is  8122.321
# The actual is  4074.4537  and prediction is  4057.5735
# The actual is  8083.9198  and prediction is  8038.0957
# The actual is  2026.9741  and prediction is  1906.7556
# The actual is  31620.00106  and prediction is  14563.323
# The actual is  1981.5819  and prediction is  2143.424
# The actual is  20781.48892  and prediction is  10202.609
# The actual is  24869.8368  and prediction is  24196.562
# The actual is  18806.14547  and prediction is  7397.2715
# The actual is  8551.347  and prediction is  8426.048
# The actual is  18218.16139  and prediction is  3203.9224
# The actual is  14210.53595  and prediction is  14007.593
# The actual is  10959.6947  and prediction is  10497.922
# The actual is  4441.21315  and prediction is  4429.7686
# The actual is  12142.5786  and prediction is  12183.59
# The actual is  10560.4917  and prediction is  10592.991
# The actual is  2897.3235  and prediction is  2860.21
# The actual is  2755.02095  and prediction is  3113.753
# The actual is  34617.84065  and prediction is  34529.047
# The actual is  22331.5668  and prediction is  26785.973
# The actual is  1625.43375  and prediction is  1575.1537
# The actual is  48517.56315  and prediction is  47939.36
# The actual is  8219.2039  and prediction is  8095.0684
# The actual is  6940.90985  and prediction is  6882.0586
# The actual is  8240.5896  and prediction is  8252.756
# The actual is  40103.89  and prediction is  40234.453
# The actual is  42983.4585  and prediction is  44446.047
# The actual is  44202.6536  and prediction is  44334.37
# The actual is  2136.88225  and prediction is  1897.2393
# The actual is  5227.98875  and prediction is  5200.411
# The actual is  10355.641  and prediction is  10193.347
# The actual is  10065.413  and prediction is  10036.548
# The actual is  1141.4451  and prediction is  1029.506
# The actual is  13012.20865  and prediction is  12882.802
# The actual is  7445.918  and prediction is  7335.6865
# The actual is  8410.04685  and prediction is  8425.507
# The actual is  6986.697  and prediction is  6707.7725
# The actual is  47896.79135  and prediction is  47421.145
# The actual is  6406.4107  and prediction is  6373.408
# The actual is  5354.07465  and prediction is  5252.933
# The actual is  17468.9839  and prediction is  21021.738
# The actual is  16776.30405  and prediction is  16411.984
# The actual is  1252.407  and prediction is  1289.5594
# The actual is  8527.532  and prediction is  8370.216
# The actual is  5261.46945  and prediction is  5223.2793
# The actual is  2362.22905  and prediction is  2256.309
# The actual is  9414.92  and prediction is  9410.133
# The actual is  10118.424  and prediction is  10000.421
# The actual is  12646.207  and prediction is  12543.89
# The actual is  20878.78443  and prediction is  8470.059
# The actual is  2632.992  and prediction is  2675.229
# The actual is  6067.12675  and prediction is  5987.2847
# The actual is  10704.47  and prediction is  10579.608
# The actual is  30166.61817  and prediction is  14734.39
# The actual is  13831.1152  and prediction is  13558.564
# The actual is  9869.8102  and prediction is  9794.274
# The actual is  2899.48935  and prediction is  3002.1672
# The actual is  21774.32215  and prediction is  22237.74
# The actual is  7050.0213  and prediction is  6866.042
# The actual is  24671.66334  and prediction is  5663.674
# The actual is  3206.49135  and prediction is  3100.4192
# The actual is  7077.1894  and prediction is  6968.078
# The actual is  5484.4673  and prediction is  5594.389
# The actual is  8605.3615  and prediction is  8818.606
# The actual is  3943.5954  and prediction is  3910.1062
# The actual is  6775.961  and prediction is  6701.002
# The actual is  4922.9159  and prediction is  4872.75
# The actual is  20773.62775  and prediction is  24171.63
# The actual is  5266.3656  and prediction is  5085.3096
# The actual is  4340.4409  and prediction is  4327.0273
# The actual is  1131.5066  and prediction is  1119.0502
# The actual is  6640.54485  and prediction is  6798.06
# The actual is  4949.7587  and prediction is  4794.4824
# The actual is  1769.53165  and prediction is  1702.2452
# The actual is  15820.699  and prediction is  14956.163
# The actual is  2480.9791  and prediction is  2345.7532
# The actual is  4399.731  and prediction is  4392.2236
# The actual is  13822.803  and prediction is  13706.312
# The actual is  13204.28565  and prediction is  13077.9375
# The actual is  9290.1395  and prediction is  9264.817
# The actual is  13880.949  and prediction is  13659.358
# The actual is  11033.6617  and prediction is  10917.71
# The actual is  9875.6804  and prediction is  9872.447
# The actual is  12829.4551  and prediction is  12536.347
# The actual is  3947.4131  and prediction is  3914.9065
# The actual is  7358.17565  and prediction is  7190.6865
# The actual is  11830.6072  and prediction is  11686.952
# The actual is  3693.428  and prediction is  3938.6475
# The actual is  14382.70905  and prediction is  14317.163
# The actual is  6593.5083  and prediction is  6562.52
# The actual is  4428.88785  and prediction is  4397.8916
# The actual is  23065.4207  and prediction is  24867.758
# The actual is  13019.16105  and prediction is  12782.378
# The actual is  11365.952  and prediction is  11273.89
# The actual is  23045.56616  and prediction is  9984.017
# The actual is  2250.8352  and prediction is  2216.9907
# The actual is  32108.66282  and prediction is  8295.896
# The actual is  3161.454  and prediction is  3135.716
# The actual is  3279.86855  and prediction is  3302.7827
# The actual is  5709.1644  and prediction is  5611.474
# The actual is  15161.5344  and prediction is  15263.113
# The actual is  14394.5579  and prediction is  14357.762
# The actual is  41676.0811  and prediction is  42076.004
# The actual is  2130.6759  and prediction is  1961.4784
# The actual is  40273.6455  and prediction is  40549.57
# The actual is  3484.331  and prediction is  3448.718
# The actual is  7640.3092  and prediction is  7544.2153
# The actual is  36124.5737  and prediction is  36233.918
# The actual is  4454.40265  and prediction is  4418.2686
# The actual is  2710.82855  and prediction is  2634.655
# The actual is  3500.6123  and prediction is  3299.8967
# The actual is  10713.644  and prediction is  10400.112
# The actual is  2680.9493  and prediction is  2713.6296
# The actual is  2217.46915  and prediction is  2550.969
# The actual is  10107.2206  and prediction is  10161.173
# The actual is  45863.205  and prediction is  46189.402
# The actual is  16450.8947  and prediction is  15316.192
# The actual is  8162.71625  and prediction is  8059.107
# The actual is  10338.9316  and prediction is  10379.454
# The actual is  29523.1656  and prediction is  32856.17
# The actual is  9800.8882  and prediction is  9494.485
# The actual is  2523.1695  and prediction is  2414.0588
# The actual is  4337.7352  and prediction is  4198.2397
# The actual is  10156.7832  and prediction is  9996.792
# The actual is  9432.9253  and prediction is  10484.386
# The actual is  8825.086  and prediction is  8792.521
# The actual is  5012.471  and prediction is  4870.044
# The actual is  8116.26885  and prediction is  7843.3184
# The actual is  51194.55914  and prediction is  37872.473
# The actual is  21098.55405  and prediction is  20604.14
# The actual is  6710.1919  and prediction is  6635.0117
# The actual is  21223.6758  and prediction is  21645.309
# The actual is  24393.6224  and prediction is  24546.42
# The actual is  9504.3103  and prediction is  9191.175
# The actual is  5699.8375  and prediction is  5716.4824
# The actual is  25656.57526  and prediction is  9423.678
# The actual is  6652.5288  and prediction is  6746.7217
# The actual is  10269.46  and prediction is  10114.283
# The actual is  15019.76005  and prediction is  15040.513
# The actual is  2741.948  and prediction is  2804.735
# The actual is  6435.6237  and prediction is  6401.801
# The actual is  11938.25595  and prediction is  11920.245
# The actual is  7261.741  and prediction is  7076.5303
# The actual is  17496.306  and prediction is  17560.809
# The actual is  33307.5508  and prediction is  27648.05
# The actual is  32787.45859  and prediction is  23553.582
# The actual is  28468.91901  and prediction is  8594.9375
# The actual is  20462.99766  and prediction is  11710.0625
# The actual is  12574.049  and prediction is  12420.222
# The actual is  3736.4647  and prediction is  3606.5728
# The actual is  4795.6568  and prediction is  4552.546
# The actual is  12032.326  and prediction is  12058.404
# The actual is  37742.5757  and prediction is  38127.316
# The actual is  46718.16325  and prediction is  38002.73
# The actual is  8334.45755  and prediction is  8259.003
# The actual is  42211.1382  and prediction is  42532.504
# The actual is  34828.654  and prediction is  34573.043
# The actual is  21771.3423  and prediction is  21388.943
# The actual is  9095.06825  and prediction is  9034.447
# The actual is  11566.30055  and prediction is  11531.181
# The actual is  1880.487  and prediction is  1793.5237
# The actual is  2457.21115  and prediction is  2407.176
# The actual is  17043.3414  and prediction is  18432.285
# The actual is  26140.3603  and prediction is  9135.591
